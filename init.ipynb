# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://docs.deepnote.com/environment/custom-initialization).

# %%
# %%bash
# # If you imported a project with a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# There's no requirements.txt, so nothing to install. This is the case with most projects.

# %%
# %%bash
# # If you have previously installed any packages into this project, we re-install them here to restore your environment.
# if test -f .deepnote/requirements.txt
#   then
#     sed -i '/jupyter/d' .deepnote/requirements.txt
#     pip install -r .deepnote/requirements.txt
#   else echo "Seems like there is nothing to restore. Most likely, you haven't installed any extra packages so far."
# fi
# Out:
# Collecting absl-py==0.9.0
#   Downloading absl-py-0.9.0.tar.gz (104 kB)
# Collecting astunparse==1.6.3
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: attrs==19.3.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 3)) (19.3.0)
# Requirement already satisfied: backcall==0.1.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 4)) (0.1.0)
# Requirement already satisfied: bleach==3.1.5 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 5)) (3.1.5)
# Collecting cachetools==4.1.0
#   Downloading cachetools-4.1.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: certifi==2020.4.5.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 7)) (2020.4.5.1)
# Requirement already satisfied: chardet==3.0.4 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 8)) (3.0.4)
# Requirement already satisfied: cycler==0.10.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 9)) (0.10.0)
# Requirement already satisfied: decorator==4.4.2 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 10)) (4.4.2)
# Requirement already satisfied: defusedxml==0.6.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 11)) (0.6.0)
# Requirement already satisfied: docopt==0.6.2 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 12)) (0.6.2)
# Requirement already satisfied: entrypoints==0.3 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 13)) (0.3)
# Collecting gast==0.3.3
#   Downloading gast-0.3.3-py2.py3-none-any.whl (9.7 kB)
# Collecting google-auth==1.16.0
#   Downloading google_auth-1.16.0-py2.py3-none-any.whl (90 kB)
# Collecting google-auth-oauthlib==0.4.1
#   Downloading google_auth_oauthlib-0.4.1-py2.py3-none-any.whl (18 kB)
# Collecting google-pasta==0.2.0
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting grpcio==1.29.0
#   Downloading grpcio-1.29.0-cp37-cp37m-manylinux2010_x86_64.whl (3.0 MB)
# Collecting h5py==2.10.0
#   Downloading h5py-2.10.0-cp37-cp37m-manylinux1_x86_64.whl (2.9 MB)
# Requirement already satisfied: idna==2.9 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 20)) (2.9)
# Requirement already satisfied: importlib-metadata==1.6.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 21)) (1.6.0)
# Requirement already satisfied: ipykernel==5.3.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 22)) (5.3.0)
# Requirement already satisfied: ipython==7.14.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 23)) (7.14.0)
# Requirement already satisfied: ipython-genutils==0.2.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 24)) (0.2.0)
# Requirement already satisfied: ipywidgets==7.5.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 25)) (7.5.1)
# Requirement already satisfied: jedi==0.17.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 26)) (0.17.0)
# Requirement already satisfied: Jinja2==2.11.2 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 27)) (2.11.2)
# Requirement already satisfied: joblib==0.15.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 28)) (0.15.1)
# Requirement already satisfied: jsonschema==3.2.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 29)) (3.2.0)
# Collecting kaggle==1.5.6
#   Downloading kaggle-1.5.6.tar.gz (58 kB)
# Collecting Keras-Preprocessing==1.1.2
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Requirement already satisfied: kiwisolver==1.2.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 32)) (1.2.0)
# Collecting Markdown==3.2.2
#   Downloading Markdown-3.2.2-py3-none-any.whl (88 kB)
# Requirement already satisfied: MarkupSafe==1.1.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 34)) (1.1.1)
# Requirement already satisfied: matplotlib==3.2.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 35)) (3.2.1)
# Requirement already satisfied: mistune==0.8.4 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 36)) (0.8.4)
# Requirement already satisfied: nbconvert==5.6.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 37)) (5.6.1)
# Requirement already satisfied: nbformat==5.0.6 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 38)) (5.0.6)
# Requirement already satisfied: numpy==1.18.4 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 39)) (1.18.4)
# Collecting oauthlib==3.1.0
#   Downloading oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Collecting opt-einsum==3.2.1
#   Downloading opt_einsum-3.2.1-py3-none-any.whl (63 kB)
# Requirement already satisfied: packaging==20.4 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 42)) (20.4)
# Requirement already satisfied: pandas==0.25.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 43)) (0.25.0)
# Requirement already satisfied: pandocfilters==1.4.2 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 44)) (1.4.2)
# Requirement already satisfied: parso==0.7.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 45)) (0.7.0)
# Requirement already satisfied: pexpect==4.8.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 46)) (4.8.0)
# Requirement already satisfied: pickleshare==0.7.5 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 47)) (0.7.5)
# Collecting Pillow==7.1.2
#   Downloading Pillow-7.1.2-cp37-cp37m-manylinux1_x86_64.whl (2.1 MB)
# Requirement already satisfied: pipreqs@ git+https://github.com/deepnote/pipreqs.git@5c94fac42a8ddd19eabd75e3de8e84bb8120afd1 from git+https://github.com/deepnote/pipreqs.git@5c94fac42a8ddd19eabd75e3de8e84bb8120afd1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 49)) (0.4.8)
# Requirement already satisfied: pluggy==0.13.1 in /opt/venv/lib/python3.7/site-packages/pluggy-0.13.1-py3.7.egg (from -r .deepnote/requirements.txt (line 50)) (0.13.1)
# Requirement already satisfied: prometheus-client==0.7.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 51)) (0.7.1)
# Requirement already satisfied: prompt-toolkit==3.0.5 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 52)) (3.0.5)
# Collecting protobuf==3.12.2
#   Downloading protobuf-3.12.2-cp37-cp37m-manylinux1_x86_64.whl (1.3 MB)
# Requirement already satisfied: ptyprocess==0.6.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 54)) (0.6.0)
# Collecting pyasn1==0.4.8
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting pyasn1-modules==0.2.8
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Requirement already satisfied: Pygments==2.6.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 57)) (2.6.1)
# Requirement already satisfied: pyparsing==2.4.7 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 58)) (2.4.7)
# Requirement already satisfied: pyrsistent==0.16.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 59)) (0.16.0)
# Requirement already satisfied: python-dateutil==2.8.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 60)) (2.8.1)
# Requirement already satisfied: python-jsonrpc-server==0.3.4 in /opt/venv/lib/python3.7/site-packages/python_jsonrpc_server-0.3.4-py3.7.egg (from -r .deepnote/requirements.txt (line 61)) (0.3.4)
# Requirement already satisfied: python-language-server==0.30.0+39.g60b5005 in /opt/venv/lib/python3.7/site-packages/python_language_server-0.30.0+39.g60b5005-py3.7.egg (from -r .deepnote/requirements.txt (line 62)) (0.30.0+39.g60b5005)
# Collecting python-slugify==4.0.0
#   Downloading python-slugify-4.0.0.tar.gz (8.8 kB)
# Requirement already satisfied: pytz==2020.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 64)) (2020.1)
# Requirement already satisfied: pyzmq==19.0.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 65)) (19.0.1)
# Requirement already satisfied: requests==2.23.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 66)) (2.23.0)
# Collecting requests-oauthlib==1.3.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting rsa==4.0
#   Downloading rsa-4.0-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: scikit-learn==0.23.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 69)) (0.23.1)
# Requirement already satisfied: scipy==1.4.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 70)) (1.4.1)
# Requirement already satisfied: Send2Trash==1.5.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 71)) (1.5.0)
# Requirement already satisfied: six==1.14.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 72)) (1.14.0)
# Collecting tensorboard==2.2.2
#   Downloading tensorboard-2.2.2-py3-none-any.whl (3.0 MB)
# Collecting tensorboard-plugin-wit==1.6.0.post3
#   Downloading tensorboard_plugin_wit-1.6.0.post3-py3-none-any.whl (777 kB)
# Collecting tensorflow==2.2.0
#   Downloading tensorflow-2.2.0-cp37-cp37m-manylinux2010_x86_64.whl (516.2 MB)
# Collecting tensorflow-estimator==2.2.0
#   Downloading tensorflow_estimator-2.2.0-py2.py3-none-any.whl (454 kB)
# Collecting termcolor==1.1.0
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
# Requirement already satisfied: terminado==0.8.3 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 78)) (0.8.3)
# Requirement already satisfied: testpath==0.4.4 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 79)) (0.4.4)
# Collecting text-unidecode==1.3
#   Downloading text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
# Requirement already satisfied: threadpoolctl==2.0.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 81)) (2.0.0)
# Requirement already satisfied: tornado==6.0.4 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 82)) (6.0.4)
# Collecting tqdm==4.46.1
#   Downloading tqdm-4.46.1-py2.py3-none-any.whl (63 kB)
# Requirement already satisfied: traitlets==4.3.3 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 84)) (4.3.3)
# Requirement already satisfied: ujson==1.35 in /opt/venv/lib/python3.7/site-packages/ujson-1.35-py3.7-linux-x86_64.egg (from -r .deepnote/requirements.txt (line 85)) (1.35)
# Collecting urllib3==1.24.3
#   Downloading urllib3-1.24.3-py2.py3-none-any.whl (118 kB)
# Requirement already satisfied: wcwidth==0.1.9 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 87)) (0.1.9)
# Requirement already satisfied: webencodings==0.5.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 88)) (0.5.1)
# Collecting Werkzeug==1.0.1
#   Downloading Werkzeug-1.0.1-py2.py3-none-any.whl (298 kB)
# Requirement already satisfied: widgetsnbextension==3.5.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 90)) (3.5.1)
# Collecting wrapt==1.12.1
#   Downloading wrapt-1.12.1.tar.gz (27 kB)
# Requirement already satisfied: yarg==0.1.9 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 92)) (0.1.9)
# Requirement already satisfied: zipp==3.1.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 93)) (3.1.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/venv/lib/python3.7/site-packages (from astunparse==1.6.3->-r .deepnote/requirements.txt (line 2)) (0.34.2)
# Requirement already satisfied: setuptools>=40.3.0 in /opt/venv/lib/python3.7/site-packages (from google-auth==1.16.0->-r .deepnote/requirements.txt (line 15)) (46.4.0)
# Requirement already satisfied: jupyter-client in /opt/venv/lib/python3.7/site-packages (from ipykernel==5.3.0->-r .deepnote/requirements.txt (line 22)) (6.1.3)
# Requirement already satisfied: jupyter-core in /opt/venv/lib/python3.7/site-packages (from nbconvert==5.6.1->-r .deepnote/requirements.txt (line 37)) (4.6.3)
# Requirement already satisfied: notebook>=4.4.1 in /opt/venv/lib/python3.7/site-packages (from widgetsnbextension==3.5.1->-r .deepnote/requirements.txt (line 90)) (7.0.0.dev0)
# Building wheels for collected packages: absl-py, kaggle, python-slugify, termcolor, wrapt
#   Building wheel for absl-py (setup.py): started
#   Building wheel for absl-py (setup.py): finished with status 'done'
#   Created wheel for absl-py: filename=absl_py-0.9.0-py3-none-any.whl size=121931 sha256=f7a8ee5029bd411a9875d4bfba53cd5972bef19271d66115cad3567de081e8af
#   Stored in directory: /home/jovyan/.cache/pip/wheels/cc/af/1a/498a24d0730ef484019e007bb9e8cef3ac00311a672c049a3e
#   Building wheel for kaggle (setup.py): started
#   Building wheel for kaggle (setup.py): finished with status 'done'
#   Created wheel for kaggle: filename=kaggle-1.5.6-py3-none-any.whl size=72859 sha256=7b65e357dda38dc460dba169da7a5b77116cb5870a8eb340897af88db6931422
#   Stored in directory: /home/jovyan/.cache/pip/wheels/aa/e7/e7/eb3c3d514c33294d77ddd5a856bdd58dc9c1fabbed59a02a2b
#   Building wheel for python-slugify (setup.py): started
#   Building wheel for python-slugify (setup.py): finished with status 'done'
#   Created wheel for python-slugify: filename=python_slugify-4.0.0-py2.py3-none-any.whl size=5486 sha256=218938ee3f614da49c70774e2fdea035459e09b92084c017ad420392d4a947a8
#   Stored in directory: /home/jovyan/.cache/pip/wheels/7c/26/30/5f3d95da00fe94d0c4a5ec5b4ffd2e1ae18545f5fa61752e52
#   Building wheel for termcolor (setup.py): started
#   Building wheel for termcolor (setup.py): finished with status 'done'
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4830 sha256=f7234155842e5bb1ac90e9b436487cf3c2f10ad147c2b24448eead011993bf0b
#   Stored in directory: /home/jovyan/.cache/pip/wheels/3f/e3/ec/8a8336ff196023622fbcb36de0c5a5c218cbb24111d1d4c7f2
#   Building wheel for wrapt (setup.py): started
#   Building wheel for wrapt (setup.py): finished with status 'done'
#   Created wheel for wrapt: filename=wrapt-1.12.1-cp37-cp37m-linux_x86_64.whl size=71569 sha256=fa0acb32e5e2db79214dacb2862366223af48026f3a158885e61ee4ceff23493
#   Stored in directory: /home/jovyan/.cache/pip/wheels/62/76/4c/aa25851149f3f6d9785f6c869387ad82b3fd37582fa8147ac6
# Successfully built absl-py kaggle python-slugify termcolor wrapt
# Installing collected packages: absl-py, astunparse, cachetools, gast, pyasn1, rsa, pyasn1-modules, google-auth, oauthlib, requests-oauthlib, google-auth-oauthlib, google-pasta, grpcio, h5py, urllib3, tqdm, text-unidecode, python-slugify, kaggle, Keras-Preprocessing, Markdown, opt-einsum, Pillow, protobuf, tensorboard-plugin-wit, Werkzeug, tensorboard, wrapt, termcolor, tensorflow-estimator, tensorflow
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.25.9
#     Uninstalling urllib3-1.25.9:
#       Successfully uninstalled urllib3-1.25.9
# Successfully installed Keras-Preprocessing-1.1.2 Markdown-3.2.2 Pillow-7.1.2 Werkzeug-1.0.1 absl-py-0.9.0 astunparse-1.6.3 cachetools-4.1.0 gast-0.3.3 google-auth-1.16.0 google-auth-oauthlib-0.4.1 google-pasta-0.2.0 grpcio-1.29.0 h5py-2.10.0 kaggle-1.5.6 oauthlib-3.1.0 opt-einsum-3.2.1 protobuf-3.12.2 pyasn1-0.4.8 pyasn1-modules-0.2.8 python-slugify-4.0.0 requests-oauthlib-1.3.0 rsa-4.0 tensorboard-2.2.2 tensorboard-plugin-wit-1.6.0.post3 tensorflow-2.2.0 tensorflow-estimator-2.2.0 termcolor-1.1.0 text-unidecode-1.3 tqdm-4.46.1 urllib3-1.24.3 wrapt-1.12.1
